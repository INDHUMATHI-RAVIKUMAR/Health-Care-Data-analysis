# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore')
import pandas as pd
df = pd.read_csv("healthcare_dataset.csv")
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Medical Condition"].unique()
# Out:
# array(['Cancer', 'Obesity', 'Diabetes', 'Asthma', 'Hypertension',
#        'Arthritis'], dtype=object)

# %%
df["Blood Type"].unique()
# Out:
# array(['B-', 'A+', 'A-', 'O+', 'AB+', 'AB-', 'B+', 'O-'], dtype=object)

# %%
df["Doctor"].unique()
# Out:
# array(['Matthew Smith', 'Samantha Davies', 'Tiffany Mitchell', ...,
#        'Deborah Sutton', 'Mary Bartlett', 'Alec May'], dtype=object)

# %%
df["Hospital"].unique()
# Out:
# array(['Sons and Miller', 'Kim Inc', 'Cook PLC', ...,
#        'Guzman Jones and Graves,', 'and Williams, Brown Mckenzie',
#        'Moreno Murphy, Griffith and'], dtype=object)

# %%
df["Insurance Provider"].unique()
# Out:
# array(['Blue Cross', 'Medicare', 'Aetna', 'UnitedHealthcare', 'Cigna'],
#       dtype=object)

# %%
df["Admission Type"].unique()
# Out:
# array(['Urgent', 'Emergency', 'Elective'], dtype=object)

# %%
df["Medication"].unique()
# Out:
# array(['Paracetamol', 'Ibuprofen', 'Aspirin', 'Penicillin', 'Lipitor'],
#       dtype=object)

# %%
df["Test Results"].unique()
# Out:
# array(['Normal', 'Inconclusive', 'Abnormal'], dtype=object)

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  datetime64[ns]
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  datetime64[ns]
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age              Date of Admission  Billing Amount  \
# count  55500.000000                          55500    55500.000000
# mean      51.539459  2021-11-01 01:02:22.443243008    25539.316097
# min       13.000000            2019-05-08 00:00:00    -2008.492140
# 25%       35.000000            2020-07-28 00:00:00    13241.224652
# 50%       52.000000            2021-11-01 00:00:00    25538.069376
# 75%       68.000000            2023-02-03 00:00:00    37820.508436
# max       89.000000            2024-05-07 00:00:00    52764.276736
# std       19.602454                            NaN    14211.454431
#
#         Room Number                 Discharge Date
# count  55500.000000                          55500
# mean     301.134829  2021-11-16 13:15:20.821621504
# min      101.000000            2019-05-09 00:00:00
# 25%      202.000000            2020-08-12 00:00:00
# 50%      302.000000            2021-11-17 00:00:00
# 75%      401.000000            2023-02-18 00:00:00
# ...

# %%
df.describe(include= "object").T
# Out:
#                     count unique            top   freq
# Name                55500  49992    DAvId muNoZ      3
# Gender              55500      2           Male  27774
# Blood Type          55500      8             A-   6969
# Medical Condition   55500      6      Arthritis   9308
# Doctor              55500  40341  Michael Smith     27
# Hospital            55500  39876      LLC Smith     44
# Insurance Provider  55500      5          Cigna  11249
# Admission Type      55500      3       Elective  18655
# Medication          55500      5        Lipitor  11140
# Test Results        55500      3       Abnormal  18627

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      27774
# Female    27726
# Name: count, dtype: int64

# %%
df['Blood Type'].value_counts()
# Out:
# Blood Type
# A-     6969
# A+     6956
# AB+    6947
# AB-    6945
# B+     6945
# B-     6944
# O+     6917
# O-     6877
# Name: count, dtype: int64

# %%
df['Admission Type'].value_counts()
# Out:
# Admission Type
# Elective     18655
# Urgent       18576
# Emergency    18269
# Name: count, dtype: int64

# %%
df['Test Results'].value_counts()
# Out:
# Test Results
# Abnormal        18627
# Normal          18517
# Inconclusive    18356
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# <h1>Medical Condition Distribution by Gender</h1>

# %%
import seaborn as sns

# Plot count plot for Gender vs. Medical Condition
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='Medical Condition', hue='Gender', palette='Set2')
plt.title('Medical Condition Distribution by Gender')
plt.xlabel('Medical Condition')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <h1>Age Distribution by Medical Condition</h1>

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='Medical Condition', y='Age', palette='muted')
plt.title('Age Distribution by Medical Condition')
plt.xlabel('Medical Condition')
plt.ylabel('Age')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <h1>Test Results Distribution by Admission Type</h1>

# %%
df.columns = df.columns.str.strip()

# Plot count plot for Test Results by Admission Type
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='Admission Type', hue='Test Results', palette='Set2')
plt.title('Test Results Distribution by Admission Type')
plt.xlabel('Admission Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <h1>The average age of patients in the dataset</h1>

# %%
average_age = df['Age'].mean()
print(f"The average age of patients is {average_age:.2f} years.")
# Out:
# The average age of patients is 51.54 years.

# %% [markdown]
# <h1>The most common medical condition among patients</h1>

# %%
most_common_condition = df['Medical Condition'].value_counts().idxmax()
print(f"The most common medical condition is {most_common_condition}.")
# Out:
# The most common medical condition is Arthritis.

# %% [markdown]
# <h1>The average billing amount for each medical condition</h1>

# %%
# Calculate average billing amount by medical condition
avg_billing_by_condition = df.groupby('Medical Condition')['Billing Amount'].mean()

# Print the average billing amount by medical condition
print("Average billing amount by medical condition:")
for condition, avg_billing in avg_billing_by_condition.items():
    print(f"{condition}: {avg_billing:.2f}")
# Out:
# Average billing amount by medical condition:
# Arthritis: 25497.33
# Asthma: 25635.25
# Cancer: 25161.79
# Diabetes: 25638.41
# Hypertension: 25497.10
# Obesity: 25805.97

# %% [markdown]
# <h1>The most number of admissions of doctor</h1>

# %%
doctor_admissions = df['Doctor'].value_counts().idxmax()
print("Doctors with most admissions: ",doctor_admissions)
# Out:
# Doctors with most admissions:  Michael Smith

# %% [markdown]
# <h1>Distribution of patients across different hospitals</h1>

# %%
hospital_distribution = df['Hospital'].value_counts()
print("Distribution of patients across hospitals: ", hospital_distribution)
# Out:
# Distribution of patients across hospitals:  Hospital
# LLC Smith                      44
# Ltd Smith                      39
# Johnson PLC                    38
# Smith Ltd                      37
# Smith PLC                      36
#                                ..
# and Montoya Flores, Boyer       1
# Carter and Dunn King,           1
# Hall, Brown Black and           1
# Peterson Scott and Thomas,      1
# Moreno Murphy, Griffith and     1
# Name: count, Length: 39876, dtype: int64

# %% [markdown]
# <h1>The oldest patient in the dataset, and their age</h1>

# %%
oldest_patient_age = df['Age'].max()
oldest_patient_name = df[df['Age'] == oldest_patient_age]['Name'].iloc[0]
print(f"The oldest patient in the dataset is {oldest_patient_name} with an age of {oldest_patient_age} years.")
# Out:
# The oldest patient in the dataset is DAVId NeWTOn with an age of 89 years.

# %% [markdown]
# <h1>The Youngest patient in the dataset, and their age</h1>

# %%
young_patient_age = df['Age'].min()
young_patient_name = df[df['Age'] == young_patient_age]['Name'].iloc[0]
print(f"The young patient in the dataset is {young_patient_name} with an age of {young_patient_age} years.")
# Out:
# The young patient in the dataset is jamES BasS phD with an age of 13 years.

# %% [markdown]
# <h1>The most frequently prescribed medication</h1>

# %%
most_frequent_medication = df['Medication'].value_counts().idxmax()
print(f"The most frequently prescribed medication is {most_frequent_medication}.")
# Out:
# The most frequently prescribed medication is Lipitor.

# %% [markdown]
# <h1>The average billing amount for patients</h1>

# %%
average_billing_amount = df['Billing Amount'].mean()
print(f"The average billing amount for patients is ${average_billing_amount:.2f}.")

# %% [markdown]
# <h1>How many male and female patients are there?</h1>

# %%
male_patients = df[df['Gender'] == 'Male'].shape[0]
female_patients = df[df['Gender'] == 'Female'].shape[0]
print(f"There are {male_patients} Male patients and {female_patients} Female patients.")
# Out:
# There are 27774 Male patients and 27726 Female patients.

# %% [markdown]
# <h2>The top three most common medical conditions and patients admitted count</h2>

# %%
top_three_medical_conditions = df['Medical Condition'].value_counts().head(3)
print("Top Three Most Common Medical Conditions:")
print(top_three_medical_conditions)
# Out:
# Top Three Most Common Medical Conditions:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Name: count, dtype: int64

# %% [markdown]
# <h1>Monthly admissions trend</h1>

# %%
try:
    df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
    df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])
except ValueError:
    df['Admission Year'] = df['Date of Admission'].dt.year
    df['Admission Month'] = df['Date of Admission'].dt.month
    df['Admission Day'] = df['Date of Admission'].dt.day
    df['Admission Weekday'] = df['Date of Admission'].dt.weekday
else:
    print("\n No exception occured \n ")
    monthly_admissions = df.groupby(['Admission Year', 'Admission Month']).size().reset_index(name='Counts')

    monthly_admissions_pivot = monthly_admissions.pivot(index='Admission Month', columns='Admission Year', values='Counts')
finally:
    plt.figure(figsize=(12, 6))
    monthly_admissions_pivot.plot(kind='line', marker='o')
    plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
    plt.title('Monthly Admissions Trend')
    plt.xlabel('Month')
    plt.ylabel('Number of Admissions')
    plt.legend(title='Year')
    plt.grid(True)
    plt.show()
# Out:
#  No exception occured

# %% [markdown]
# <h1>Weekly admissions trend</h1>

# %%
weekly_admissions = df.groupby(['Admission Year', 'Admission Weekday']).size().reset_index(name='Counts')
weekly_admissions_pivot = weekly_admissions.pivot(index='Admission Weekday', columns='Admission Year', values='Counts')

plt.figure(figsize=(12, 6))
weekly_admissions_pivot.plot(kind='line', marker='o')
plt.title('Weekly Admissions Trend')
plt.xlabel('Weekday')
plt.ylabel('Number of Admissions')
plt.xticks(ticks=range(7), labels=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.legend(title='Year')
plt.grid(True)
plt.show()

# %% [markdown]
# <h1>Univariate Analysis</h1>

# %% [markdown]
# <h3>Histograms, box plots, bar plots, etc., for numerical and categorical variables</h3>

# %% [markdown]
# <h1>Box plot for one numerical column</h1>

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(df['Age'], patch_artist=True, boxprops=dict(facecolor='lightblue', color='black'))
plt.title('Age Distribution')
plt.ylabel('Age')
plt.grid(True)
plt.show()

# %% [markdown]
# <h1>There is no outliers in Age distribution </h1>

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(df['Billing Amount'], patch_artist=True, boxprops=dict(facecolor='lightgreen', color='black'))
plt.title('Billing Amount Distribution')
plt.ylabel('Billing Amount')
plt.grid(True)
plt.show()

# %% [markdown]
# <h1>Bivariate Analysis</h1>

# %% [markdown]
# <h3>Analyze relationships between pairs of variables.
# Scatter plots, heatmaps, correlation matrices to identify patterns and correlations</h3>

# %% [markdown]
# <h2>Scatter plot for 2 numerical column</h2>

# %%
import seaborn as sns
sns.scatterplot( x='Age', y= 'Billing Amount', data = df)
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# # Inference
# <H2> Scatterplot says the most data points are clustered together, there might be a few outliers with unusally high or low billings for theri age</h2>
# <h3>There seems to be a positive correlation between Age and billing amount </h3>

# %%
selected_col = ['Age','Billing Amount']
df_selcted = df[selected_col]
correlation  = df_selcted.corr()
plt.figure(figsize=(5, 3))
sns.heatmap(correlation, annot = True , cmap = 'coolwarm' , linewidth = 5, fmt = '.2f')
plt.title('Heatmap of Age Vs Billing amount')
plt.show()

# %% [markdown]
# <h2> Overall the heatmap suggest a slightly positive relationship between Age and Billing amount. </h2>

# %% [markdown]
# <h1>Multivariate Analysis</h1>

# %% [markdown]
# <h3>Explore interactions between multiple variables.
# Pair plots (scatter matrix), parallel coordinates plots, etc., to visualize complex relationships.</h3>

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# <h1>Hypothesis Testing </h1>

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %% [markdown]
# <h2> One sample T-test</h2>

# %%
from scipy.stats import ttest_1samp
hm = 51.4  # HYPOTHESISED MEAN of Age category 
t_stat, p_value = ttest_1samp(df['Age'],hm)
alpha = 0.05 # acceptance error percent
print(f"T-statistic:{t_stat}")
print(f"P-value:{p_value}")
if p_value<alpha:
    print(f"Reject null hypothesis at alpha ={alpha}")
else:
    print(f"Faild to reject null hypothesis at alpha = {alpha}")
# Out:
# T-statistic:1.6760386522644164
# P-value:0.09373625448898289
# Faild to reject null hypothesis at alpha = 0.05

# %% [markdown]
# <h3> Since the p value is greater than the significance level 0.05, we fail to reject the null hypothesis</h3>
# <h4> If we increase the Significance level the Hypothesis result may be change at mean value</h4>

# %% [markdown]
# <h2> Independent T-test</h2>

# %%
import numpy as np
import scipy.stats as stats
male= df[df['Gender']=='Male']
female= df[df['Gender']=='Female']
male_region = male['Billing Amount']
female_region = female['Billing Amount']
male_group = np.array(male_region)
female_group = np.array(female_region)
statistic,p_value = stats.ttest_ind(a=male_region, b=female_region, equal_var = True) # independant 2 catogories 
print("P-VALUE",p_value,"STATISTIC-VALUE",statistic)
alpha = 0.05
if p_value < alpha:
    print(f"Reject null hypothesis at alpha ={alpha}")
else:
    print(f"Faild to reject null hypothesis at alpha = {alpha}")
# Out:
# P-VALUE 0.2554373668991072 STATISTIC-VALUE 1.13725319047914
# Faild to reject null hypothesis at alpha = 0.05

# %% [markdown]
# <h3> Since the p value is greater than the significance level 0.05, we fail to reject the null hypothesis.</h3>
# <h3> This means that, based on the data, there is not enough evidence to conclude that there is a significant difference in the mean billing amounts between males and females </h3>

# %% [markdown]
# <h1> CHI-SQUARE TEST</h1>

# %% [markdown]
# <h3> The chi-square test is used to test the independence of two categorical variables</h3>

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import chi2_contingency

# %%
contingency_table = pd.crosstab(df["Hospital"],df["Insurance Provider"])
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)
print(f'Chi-square stattistic:{chi2}')
print(f'P_value :{p}')
print(f'Degrees of freedom:{dof}')
print('Expected frequencies:')
print(expected)
# Out:
# Chi-square stattistic:177304.36753053722
# P_value :1.388432701954476e-203
# Degrees of freedom:159500
# Expected frequencies:
# [[0.19663063 0.19926126 0.20268468 0.20097297 0.20045045]
#  [0.19663063 0.19926126 0.20268468 0.20097297 0.20045045]
#  [0.19663063 0.19926126 0.20268468 0.20097297 0.20045045]
#  ...
#  [0.19663063 0.19926126 0.20268468 0.20097297 0.20045045]
#  [0.19663063 0.19926126 0.20268468 0.20097297 0.20045045]
#  [0.19663063 0.19926126 0.20268468 0.20097297 0.20045045]]

# %%
if dof < chi2:
    print(f"Reject null hypothesis at alpha ={alpha}")
else:
    print(f"Faild to reject null hypothesis at alpha = {alpha}")
# Out:
# Reject null hypothesis at alpha =0.05

# %% [markdown]
# <h2> P value is extremely small which is significantly less than the typical significance level of 0.05.</h2>
# <h3>This indicates strong evidence to reject the Null hypothesis.</h3>
# <h3>The result suggest that the choice of Hospital and Insurance provider are not independent of each other </h3>
